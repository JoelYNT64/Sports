# %%
import pandas as pd
from datetime import datetime

# %%
#from collections import Counter

#my_list = ["apple", "banana", "apple", "orange", "banana", "banana"]

# Count occurrences
#count_dict = Counter(cols)
#count_dict# Output: {'banana': 3, 'apple': 2, 'orange': 1}

# %% [markdown]
# ## Datasets

# %%
df_AGK= pd.read_csv("../Data/Passes (GK).csv")
df_AGK = df_AGK.rename(columns={"Launch%": "Pa Launch%", 
                                "AvgLen": "Pa AvgLen"})
df_AGK = df_AGK.drop(columns=["Att (GK).1"])
df_AGK
# Out:
#         Rk            Team        Date  Att (GK) Unnamed: 4            Opp  \
# 0        1        Dortmund  2025-01-10        69        NaN     Leverkusen
# 1        2      Strasbourg  2025-02-02        69          @         Rennes
# 2        3       Barcelona  2024-11-10        65          @  Real Sociedad
# 3        4       St. Pauli  2025-02-15        65        NaN       Freiburg
# 4        5   Saint-Étienne  2024-12-13        62          @       Toulouse
# ...    ...             ...         ...       ...        ...            ...
# 2837  2838          Napoli  2024-08-31         8        NaN          Parma
# 2838  2839        Toulouse  2025-03-30         6        NaN          Brest
# 2839  2840          Getafe  2024-10-05         6        NaN        Osasuna
# 2840  2841        Mallorca  2024-08-18         5        NaN    Real Madrid
# 2841  2842  Rayo Vallecano  2024-08-18         4          @  Real Sociedad
#
# ...

# %%
df_ArW= pd.read_csv("../Data/Aeral Duels.csv")
df_ArW = df_ArW.drop(columns=["Won.1"])
df_ArW
# Out:
#         Rk            Team        Date  Won Unnamed: 4            Opp  \
# 0        1           Lecce  2025-04-06   41        NaN        Venezia
# 1        2      Valladolid  2024-11-22   39          @         Getafe
# 2        3    Union Berlin  2025-03-02   38        NaN  Holstein Kiel
# 3        4          Bochum  2024-12-22   38        NaN     Heidenheim
# 4        5       Brentford  2024-11-09   37        NaN    Bournemouth
# ...    ...             ...         ...  ...        ...            ...
# 2837  2838       Paris S-G  2025-03-08    2          @         Rennes
# 2838  2839          Girona  2024-09-15    1        NaN      Barcelona
# 2839  2840          Girona  2024-08-15    1          @          Betis
# 2840  2841  Rayo Vallecano  2025-03-09    1          @    Real Madrid
# 2841  2842          Girona  2024-12-07    0        NaN    Real Madrid
#
#                     Comp Result  GF  GA  GD  Poss  G-PK  PK  PKatt  PKm  Lost  \
# ...

# %%
df_AtD= pd.read_csv("../Data/Take-Ons.csv")
df_AtD = df_AtD.rename(columns={"Att": "Att To"})
df_AtD = df_AtD.drop(columns=["Att.1"])
df_AtD
# Out:
#         Rk             Team        Date  Att To Unnamed: 4             Opp  \
# 0        1      Real Madrid  2024-11-09      46        NaN         Osasuna
# 1        2         West Ham  2024-12-03      45          @  Leicester City
# 2        3         Dortmund  2025-01-17      43          @  Eint Frankfurt
# 3        4  Manchester City  2025-03-15      42        NaN        Brighton
# 4        5          Chelsea  2024-12-22      42          @         Everton
# ...    ...              ...         ...     ...        ...             ...
# 2837  2838            Genoa  2024-10-31       4        NaN      Fiorentina
# 2838  2839           Empoli  2025-03-09       4        NaN            Roma
# 2839  2840           Napoli  2025-02-15       3          @           Lazio
# 2840  2841    Holstein Kiel  2025-01-24       2          @       Wolfsburg
# 2841  2842           Alavés  2025-02-15       2          @         Leganés
#
# ...

# %%
df_Car= pd.read_csv("../Data/Carries.csv")
df_Car = df_Car.rename(columns={"1/3": "Last3rd Car"})
df_Car = df_Car.drop(columns=["Carries.1", "Dis", "Rec", "CPA", "Rec", "PrgR", "Mis"])
df_Car
# Out:
#         Rk           Team        Date  Carries Unnamed: 4         Opp  \
# 0        1      Paris S-G  2024-10-27      815          @   Marseille
# 1        2  Bayern Munich  2024-12-07      789        NaN  Heidenheim
# 2        3      Marseille  2024-08-31      769          @    Toulouse
# 3        4     Leverkusen  2024-11-23      742        NaN  Heidenheim
# 4        5      Paris S-G  2025-04-05      718        NaN      Angers
# ...    ...            ...         ...      ...        ...         ...
# 2837  2838          Reims  2025-03-29      107        NaN   Marseille
# 2838  2839       Mainz 05  2024-09-20      104          @    Augsburg
# 2839  2840     Heidenheim  2025-02-23      103          @  RB Leipzig
# 2840  2841         Getafe  2025-02-09      102          @      Alavés
# 2841  2842         Getafe  2024-09-25       98          @   Barcelona
#
#                Comp Result  GF  GA  ...  Poss  G-PK  PK  PKatt  PKm  TotDist  \
# ...

# %%
df_CrA= pd.read_csv("../Data/Crosses (GK).csv")
df_CrA = df_CrA.rename(columns={"Opp": "OppCr", "Opp.1": "Opp"})
df_CrA= df_CrA.drop(columns=["Opp.2"])
df_CrA
# Out:
#         Rk             Team        Date  OppCr Unnamed: 4             Opp  \
# 0        1         Mainz 05  2024-12-21     48          @  Eint Frankfurt
# 1        2       Valladolid  2024-12-13     45        NaN        Valencia
# 2        3   Leicester City  2024-12-26     44          @       Liverpool
# 3        4          Leganés  2025-01-26     42          @   Athletic Club
# 4        5          Leganés  2024-11-30     42          @          Alavés
# ...    ...              ...         ...    ...        ...             ...
# 2837  2838  Manchester City  2024-10-26      1        NaN     Southampton
# 2838  2839       Leverkusen  2025-02-15      1        NaN   Bayern Munich
# 2839  2840            Milan  2024-08-24      1          @           Parma
# 2840  2841            Brest  2024-08-17      1        NaN       Marseille
# 2841  2842    Bayern Munich  2024-10-06      0          @  Eint Frankfurt
#
#                     Comp Result  GF  GA  GD  Poss  G-PK  PK  PKatt  PKm  Stp  \
# ...

# %%
df_Crd= pd.read_csv("../Data/Cards and Fouls.csv")
#df_CrA = df_CrA.rename(columns={"Opp": "OppCr", "Opp.1": "Opp"})
df_Crd = df_Crd.drop(columns=["CrdY.1"])
df_Crd
# Out:
#         Rk           Team        Date  CrdY Unnamed: 4         Opp  \
# 0        1     Las Palmas  2024-10-21     9          @    Valencia
# 1        2     Las Palmas  2025-03-09     8          @       Betis
# 2        3        Osasuna  2025-01-24     8          @  Las Palmas
# 3        4  Werder Bremen  2025-01-31     8        NaN    Mainz 05
# 4        5       Cagliari  2024-11-04     8          @       Lazio
# ...    ...            ...         ...   ...        ...         ...
# 2837  2838          Lecce  2025-01-26     0        NaN       Inter
# 2838  2839          Lecce  2025-01-05     0        NaN       Genoa
# 2839  2840          Lecce  2024-11-08     0        NaN      Empoli
# 2840  2841          Lecce  2024-10-20     0        NaN  Fiorentina
# 2841  2842          Lecce  2024-08-19     0        NaN    Atalanta
#
#                Comp Result  GF  GA  ...  Poss  G-PK  PK  PKatt  PKm  CrdR  \
# 0        es La Liga  W 3-2   3   2  ...    52     3   0      0    0     0
# ...

# %%
df_GcA= pd.read_csv("../Data/Goal Creating-Actions.csv")
df_GcA = df_GcA.rename(columns={"PassLive": "PassLive Gc",
                                "PassDead": "PassDead Gc",
                                "TO": "TO Gc",
                                "Fld": "Fld Gc",
                                "Def": "Def-Gc",
                                "Sh": "Sh-Gc"})
df_GcA = df_GcA.drop(columns=["GCA.1"])
df_GcA
# Out:
#         Rk            Team        Date  GCA Unnamed: 4            Opp  \
# 0        1  Eint Frankfurt  2024-11-02   13        NaN         Bochum
# 1        2          Monaco  2025-02-15   13        NaN         Nantes
# 2        3            Nice  2024-09-20   12        NaN  Saint-Étienne
# 3        4   Athletic Club  2025-02-23   12        NaN     Valladolid
# 4        5       Paris S-G  2024-08-23   12        NaN    Montpellier
# ...    ...             ...         ...  ...        ...            ...
# 2837  2838           Lecce  2024-10-05    0          @        Udinese
# 2838  2839           Lecce  2024-09-27    0          @          Milan
# 2839  2840           Lecce  2024-09-15    0          @         Torino
# 2840  2841           Lecce  2024-08-24    0          @          Inter
# 2841  2842           Lecce  2024-08-19    0        NaN       Atalanta
#
#                Comp Result  GF  GA  ...  PK  PKatt  PKm  PassLive Gc  \
# ...

# %%
df_GKA= pd.read_csv("../Data/Goal Kicks (GK).csv")
df_GKA = df_GKA.rename(columns={"Att": "GK Att"})
df_GKA = df_GKA.drop(columns=["Att.1"])
df_GKA
# Out:
#         Rk             Team        Date  GK Att Unnamed: 4             Opp  \
# 0        1            Lecce  2024-11-02      24          @         Bologna
# 1        2         Augsburg  2025-03-08      20          @        Dortmund
# 2        3          Leganés  2025-01-26      20          @   Athletic Club
# 3        4         Cagliari  2025-01-11      20          @           Milan
# 4        5       Las Palmas  2024-11-08      19          @  Rayo Vallecano
# ...    ...              ...         ...     ...        ...             ...
# 2837  2838             Como  2024-10-04       0          @          Napoli
# 2838  2839       Fiorentina  2024-09-01       0        NaN           Monza
# 2839  2840        Stuttgart  2025-01-15       0        NaN      RB Leipzig
# 2840  2841            Genoa  2025-02-02       0          @      Fiorentina
# 2841  2842  Nott'ham Forest  2024-11-30       0        NaN    Ipswich Town
#
# ...

# %%
df_Gls= pd.read_csv("../Data/Shooting.csv")
df_Gls = df_Gls.drop(columns=["Gls.1", "Gls"])
df_Gls
# Out:
#         Rk            Team        Date Unnamed: 4            Opp  \
# 0        1            Nice  2024-09-20        NaN  Saint-Étienne
# 1        2       Barcelona  2024-08-31        NaN     Valladolid
# 2        3   Athletic Club  2025-02-23        NaN     Valladolid
# 3        4  Eint Frankfurt  2024-11-02        NaN         Bochum
# 4        5          Monaco  2025-02-15        NaN         Nantes
# ...    ...             ...         ...        ...            ...
# 2837  2838           Lecce  2024-10-05          @        Udinese
# 2838  2839           Lecce  2024-09-27          @          Milan
# 2839  2840           Lecce  2024-09-15          @         Torino
# 2840  2841           Lecce  2024-08-24          @          Inter
# 2841  2842           Lecce  2024-08-19        NaN       Atalanta
#
#                Comp Result  GF  GA  GD  ...  PKatt  PKm  Sh  G/Sh  G/SoT  SoT  \
# 0        fr Ligue 1  W 8-0   8   0   8  ...      1    0  17  0.35   0.55   11
# ...

# %%
df_Misc= pd.read_csv("../Data/Misc.csv")
df_Misc = df_Misc.drop(columns=["Off.1"])
df_Misc
# Out:
#         Rk         Team        Date  Off Unnamed: 4         Opp        Comp  \
# 0        1  Real Madrid  2024-10-26   12        NaN   Barcelona  es La Liga
# 1        2     Mallorca  2024-12-03   11        NaN   Barcelona  es La Liga
# 2        3       Alavés  2025-02-02   11          @   Barcelona  es La Liga
# 3        4       Alavés  2024-10-06   11        NaN   Barcelona  es La Liga
# 4        5      Osasuna  2024-09-28   10        NaN   Barcelona  es La Liga
# ...    ...          ...         ...  ...        ...         ...         ...
# 2837  2838        Lecce  2024-11-02    0          @     Bologna  it Serie A
# 2838  2839        Lecce  2024-10-26    0          @      Napoli  it Serie A
# 2839  2840        Lecce  2024-10-20    0        NaN  Fiorentina  it Serie A
# 2840  2841        Lecce  2024-09-15    0          @      Torino  it Serie A
# 2841  2842        Lecce  2024-08-24    0          @       Inter  it Serie A
#
# ...

# %%
df_OPA= pd.read_csv("../Data/Sweeper (GK).csv")
df_OPA = df_OPA.drop(columns=["#OPA.1"])
df_OPA
# Out:
#         Rk       Team        Date  #OPA Unnamed: 4              Opp  \
# 0        1  Barcelona  2024-11-23    12          @       Celta Vigo
# 1        2       Como  2025-03-29    12        NaN           Empoli
# 2        3  Barcelona  2024-12-21     9        NaN  Atlético Madrid
# 3        4  Barcelona  2024-12-15     9        NaN          Leganés
# 4        5  Barcelona  2024-11-10     9          @    Real Sociedad
# ...    ...        ...         ...   ...        ...              ...
# 2837  2838      Lecce  2024-10-26     0          @           Napoli
# 2838  2839      Lecce  2024-10-05     0          @          Udinese
# 2839  2840      Lecce  2024-09-21     0        NaN            Parma
# 2840  2841      Lecce  2024-09-15     0          @           Torino
# 2841  2842      Lecce  2024-08-24     0          @            Inter
#
#             Comp Result  GF  GA  GD  Poss  G-PK  PK  PKatt  PKm  AvgDist  \
# 0     es La Liga  D 2-2   2   2   0    59     2   0      0    0     23.7
# ...

# %%
df_Pas= pd.read_csv("../Data/Passing.csv")
df_Pas = df_Pas.rename(columns={"Cmp.2": "Cmp 5-15", "Att.1": "Att 5-15", "Cmp%.1": "Cmp% 5-15", 
                                "Cmp.3": "Cmp 15-30", "Att.2": "Att 15-30", "Cmp%.2": "Cmp% 15-30",
                                "Cmp.4": "Cmp 30+", "Att.3": "Att 30+", "Cmp%.3": "Cmp% 30+",
                                "1/3": "Last3rd PA", 
                                "PrgDist": "PrgDist Pas", 
                                "TotDist": "TotDist Pas", 
                                "Att": "Pas Att"})
df_Pas = df_Pas.drop(columns=["Cmp.1"])
df_Pas
# Out:
#         Rk           Team        Date  Cmp Unnamed: 4            Opp  \
# 0        1      Paris S-G  2024-11-30  973        NaN         Nantes
# 1        2  Bayern Munich  2024-12-07  949        NaN     Heidenheim
# 2        3      Paris S-G  2025-04-05  914        NaN         Angers
# 3        4     Leverkusen  2024-11-23  897        NaN     Heidenheim
# 4        5  Bayern Munich  2025-02-07  883        NaN  Werder Bremen
# ...    ...            ...         ...  ...        ...            ...
# 2837  2838  Newcastle Utd  2024-08-17  128        NaN    Southampton
# 2838  2839         Getafe  2025-01-18  126        NaN      Barcelona
# 2839  2840          Reims  2025-03-29  124        NaN      Marseille
# 2840  2841   Union Berlin  2025-03-15  108        NaN  Bayern Munich
# 2841  2842         Getafe  2024-09-25  103          @      Barcelona
#
#                     Comp Result  GF  GA  ...  Cmp 5-15  Att 5-15  Cmp% 5-15  \
# ...

# %%
df_PkA= pd.read_csv("../Data/PKs (GK).csv")
df_PkA = df_PkA.drop(columns=["PKatt.1", "PKm.1"])
df_PkA = df_PkA.rename(columns={"PKatt.2": "PKdef",
                                "Save%": "Missed PK%", 
                                "PKsv": "PKms"})
df_PkA
# Out:
#         Rk         Team        Date  PKatt Unnamed: 4            Opp  \
# 0        1       Wolves  2024-11-30      3        NaN    Bournemouth
# 1        2      Udinese  2025-01-26      2        NaN           Roma
# 2        3      Udinese  2024-10-30      2          @        Venezia
# 3        4     Augsburg  2024-11-22      2          @  Bayern Munich
# 4        5  Montpellier  2024-12-01      2        NaN          Lille
# ...    ...          ...         ...    ...        ...            ...
# 2837  2838        Lecce  2024-10-05      0          @        Udinese
# 2838  2839        Lecce  2024-09-27      0          @          Milan
# 2839  2840        Lecce  2024-09-21      0        NaN          Parma
# 2840  2841        Lecce  2024-09-15      0          @         Torino
# 2841  2842        Lecce  2024-08-31      0        NaN       Cagliari
#
#                     Comp Result  GF  GA  GD  Poss  G-PK  PK  PKm  PKdef  PKA  \
# ...

# %%
df_PkD= pd.read_csv("../Data/Goals Allowed (GK).csv")
df_PkD = df_PkD.drop(columns=["PKA.1", "PKA.2", "PKatt.1", "PKm.1"])
df_PkD = df_PkD.rename(columns={"PKA": "PKAg",
                                "Save%": "PK Save%", 
                                "FK": "FK Ag",
                                "CK": "CKG",
                                "OG": "OGK"})
df_PkD
# Out:
#         Rk         Team        Date  PKAg Unnamed: 4            Opp  \
# 0        1       Wolves  2024-11-30     3        NaN    Bournemouth
# 1        2      Udinese  2025-01-26     2        NaN           Roma
# 2        3      Udinese  2024-10-30     2          @        Venezia
# 3        4     Augsburg  2024-11-22     2          @  Bayern Munich
# 4        5  Montpellier  2024-12-01     2        NaN          Lille
# ...    ...          ...         ...   ...        ...            ...
# 2837  2838        Lecce  2024-10-05     0          @        Udinese
# 2838  2839        Lecce  2024-09-27     0          @          Milan
# 2839  2840        Lecce  2024-09-21     0        NaN          Parma
# 2840  2841        Lecce  2024-09-15     0          @         Torino
# 2841  2842        Lecce  2024-08-31     0        NaN       Cagliari
#
#                     Comp Result  GF  GA  ...  G-PK  PK  PKatt  PKm  PKsv  \
# 0     eng Premier League  L 2-4   2   4  ...     2   0      0    0     0
# ...

# %%
df_PsT= pd.read_csv("../Data/Pass Types.csv")
df_PsT = df_PsT.rename(columns={"Live": "Live Pas",
                                "FK": "Pas FK",
                                "Off": "Ps Off",
                                "Blocks": "PTo"})
df_PsT = df_PsT.drop(columns=["Live.1"])
df_PsT
# Out:
#         Rk           Team        Date  Live Pas Unnamed: 4            Opp  \
# 0        1      Paris S-G  2024-11-30      1032        NaN         Nantes
# 1        2  Bayern Munich  2024-12-07      1000        NaN     Heidenheim
# 2        3     Leverkusen  2024-11-23       952        NaN     Heidenheim
# 3        4      Paris S-G  2025-04-05       948        NaN         Angers
# 4        5  Bayern Munich  2025-02-07       921        NaN  Werder Bremen
# ...    ...            ...         ...       ...        ...            ...
# 2837  2838  Hellas Verona  2025-02-15       170          @          Milan
# 2838  2839   Union Berlin  2025-03-15       170        NaN  Bayern Munich
# 2839  2840          Reims  2025-03-29       170        NaN      Marseille
# 2840  2841  Newcastle Utd  2024-08-17       163        NaN    Southampton
# 2841  2842         Getafe  2024-09-25       158          @      Barcelona
#
#                     Comp Result  GF  GA  ...  Sw  Crs  TI  CK  In  Out  Str  \
# ...

# %%
df_Rec= pd.read_csv("../Data/Receiving.csv")
df_Rec = df_Rec.rename(columns={"1/3": "Last3rd Rec"})
df_Rec = df_Rec.drop(columns=["Rec.1", "PrgR", "Carries", "TotDist", "PrgDist", "PrgC"])
df_Rec
# Out:
#         Rk           Team        Date  Rec Unnamed: 4            Opp  \
# 0        1      Paris S-G  2024-11-30  967        NaN         Nantes
# 1        2  Bayern Munich  2024-12-07  946        NaN     Heidenheim
# 2        3      Paris S-G  2025-04-05  912        NaN         Angers
# 3        4     Leverkusen  2024-11-23  890        NaN     Heidenheim
# 4        5  Bayern Munich  2025-02-07  878        NaN  Werder Bremen
# ...    ...            ...         ...  ...        ...            ...
# 2837  2838  Newcastle Utd  2024-08-17  127        NaN    Southampton
# 2838  2839         Getafe  2025-01-18  126        NaN      Barcelona
# 2839  2840          Reims  2025-03-29  121        NaN      Marseille
# 2840  2841   Union Berlin  2025-03-15  108        NaN  Bayern Munich
# 2841  2842         Getafe  2024-09-25  102          @      Barcelona
#
#                     Comp Result  GF  GA  ...  Poss  G-PK  PK  PKatt  PKm  \
# ...

# %%
df_ScA= pd.read_csv("../Data/Shot-Creating Actions.csv")
df_ScA = df_ScA.rename(columns={"PassLive": "PassLive Sc",
                                         "PassDead": "PassDead Sc",
                                         "TO": "TO Sc",
                                         "Sh": "Sh-Sh", 
                                         "Fld": "Fld Sc",
                                         "Def": "Def-Sc"})
df_ScA = df_ScA.drop(columns=["SCA.1"])
df_ScA
# Out:
#         Rk             Team        Date  SCA Unnamed: 4             Opp  \
# 0        1        Liverpool  2025-01-18   68          @       Brentford
# 1        2  Manchester City  2024-09-22   64        NaN         Arsenal
# 2        3    Bayern Munich  2024-11-22   61        NaN        Augsburg
# 3        4          Arsenal  2024-09-28   58        NaN  Leicester City
# 4        5        Barcelona  2025-03-02   58        NaN   Real Sociedad
# ...    ...              ...         ...  ...        ...             ...
# 2837  2838             Lyon  2024-08-24    2        NaN          Monaco
# 2838  2839         Valencia  2024-10-27    1          @          Getafe
# 2839  2840    Real Sociedad  2024-09-01    1          @          Getafe
# 2840  2841    Werder Bremen  2024-09-21    0        NaN   Bayern Munich
# 2841  2842    Real Sociedad  2025-03-02    0          @       Barcelona
#
#                     Comp Result  GF  GA  ...  PK  PKatt  PKm  PassLive Sc  \
# ...

# %%
df_ShA= pd.read_csv("../Data/Basic (GK).csv")
df_ShA = df_ShA.drop(columns=["SoTA.1"])
df_ShA
# Out:
#         Rk            Team        Date  SoTA Unnamed: 4            Opp  \
# 0        1      Valladolid  2025-02-23    16          @  Athletic Club
# 1        2  Leicester City  2024-09-28    16          @        Arsenal
# 2        3        Augsburg  2024-11-22    14          @  Bayern Munich
# 3        4        Espanyol  2024-09-21    14          @    Real Madrid
# 4        5      Las Palmas  2025-01-19    13          @    Real Madrid
# ...    ...             ...         ...   ...        ...            ...
# 2837  2838            Lens  2025-01-26     0        NaN         Angers
# 2838  2839          Monaco  2024-12-14     0          @          Reims
# 2839  2840          Monaco  2024-08-24     0          @           Lyon
# 2840  2841           Lecce  2024-12-15     0        NaN          Monza
# 2841  2842           Lecce  2024-09-15     0          @         Torino
#
#                     Comp Result  GF  GA  GD  Poss  G-PK  PK  PKatt  PKm  \
# ...

# %%
df_Tch= pd.read_csv("../Data/Touches.csv")
df_Tch = df_Tch.rename(columns={"Def 3rd": "Tch Def 3rd",
                                "Mid 3rd": "Tch Mid 3rd",
                                "Att 3rd": "Tch Att 3rd",
                                "Live": "Live Tch"})
df_Tch = df_Tch.drop(columns=["Touches.1"])
df_Tch
# Out:
#         Rk           Team        Date  Touches Unnamed: 4            Opp  \
# 0        1      Paris S-G  2024-11-30     1188        NaN         Nantes
# 1        2  Bayern Munich  2024-12-07     1134        NaN     Heidenheim
# 2        3      Paris S-G  2025-04-05     1082        NaN         Angers
# 3        4     Leverkusen  2024-11-23     1073        NaN     Heidenheim
# 4        5  Bayern Munich  2025-02-07     1046        NaN  Werder Bremen
# ...    ...            ...         ...      ...        ...            ...
# 2837  2838          Parma  2025-02-22      329        NaN        Bologna
# 2838  2839         Torino  2024-10-05      328          @          Inter
# 2839  2840         Getafe  2024-09-25      327          @      Barcelona
# 2840  2841  Hellas Verona  2025-02-15      326          @          Milan
# 2841  2842  Newcastle Utd  2024-08-17      317        NaN    Southampton
#
#                     Comp Result  GF  GA  ...  PK  PKatt  PKm  Def Pen  \
# ...

# %%
df_Tkl= pd.read_csv("../Data/Defensive Actions.csv")
df_Tkl = df_Tkl.drop(columns=["Tkl.1"])
df_Tkl = df_Tkl.rename(columns={"Def 3rd": "Tkl Def 3rd",
                                "Mid 3rd": "Tkl Mid 3rd",
                                "Att 3rd": "Tkl Att 3rd",
                                "Lost": "Lost Tkl",
                                "Blocks": "Ints",
                                "Sh": "BlcSh", 
                                "Att": "Tkl Att"})
df_Tkl
# Out:
#         Rk            Team        Date  Tkl Unnamed: 4             Opp  \
# 0        1  Leicester City  2024-12-03   35        NaN        West Ham
# 1        2     Southampton  2025-02-01   34          @    Ipswich Town
# 2        3           Brest  2025-01-18   34          @          Rennes
# 3        4           Lecce  2024-11-02   34          @         Bologna
# 4        5  Manchester Utd  2024-11-10   33        NaN  Leicester City
# ...    ...             ...         ...  ...        ...             ...
# 2837  2838      Las Palmas  2024-09-30    4          @      Villarreal
# 2838  2839   Athletic Club  2024-09-19    4          @         Leganés
# 2839  2840      Fiorentina  2025-02-06    4        NaN           Inter
# 2840  2841      Fiorentina  2024-10-31    3          @           Genoa
# 2841  2842      RB Leipzig  2024-11-30    3        NaN       Wolfsburg
#
#                     Comp Result  GF  GA  ...  Tkl%  Lost Tkl  Ints  BlcSh  \
# ...

# %%
df_xG= pd.read_csv("../Data/Expected Stats.csv")
df_xG = df_xG.drop(columns=["xG.1", "Sh", "G/Sh", "G/SoT", "SoT", "SoT%", "Dist"])
df_xG = df_xG.rename(columns={"FK": "FKAtt"})
df_xG
# Out:
#         Rk           Team        Date   xG Unnamed: 4             Opp  \
# 0        1      Marseille  2025-02-15  6.1        NaN   Saint-Étienne
# 1        2    Real Madrid  2025-01-19  5.9        NaN      Las Palmas
# 2        3      Liverpool  2024-12-22  5.6          @       Tottenham
# 3        4           Roma  2024-12-22  5.4        NaN           Parma
# 4        5        Chelsea  2024-12-04  5.2          @     Southampton
# ...    ...            ...         ...  ...        ...             ...
# 2837  2838  Werder Bremen  2024-09-21  0.0        NaN   Bayern Munich
# 2838  2839  Newcastle Utd  2024-11-30  0.0          @  Crystal Palace
# 2839  2840           Lyon  2024-08-24  0.0        NaN          Monaco
# 2840  2841  Real Sociedad  2025-03-02  0.0          @       Barcelona
# 2841  2842  Real Sociedad  2024-09-01  0.0          @          Getafe
#
#                     Comp Result  GF  GA  ...  xGD  npxGD  xAG   xA  G-xG  \
# ...

# %%
df_xGK= pd.read_csv("../Data/Expected Stats (GK).csv")
df_xGK = df_xGK.drop(columns=["PSxG.1"])
df_xGK
# Out:
#         Rk           Team        Date  PSxG Unnamed: 4              Opp  \
# 0        1     Valladolid  2024-11-30   5.9        NaN  Atlético Madrid
# 1        2     Valladolid  2025-02-23   5.8          @    Athletic Club
# 2        3     Hoffenheim  2025-01-15   5.6          @    Bayern Munich
# 3        4         Angers  2025-03-02   5.6        NaN         Toulouse
# 4        5  Holstein Kiel  2025-02-01   5.5          @    Bayern Munich
# ...    ...            ...         ...   ...        ...              ...
# 2837  2838         Fulham  2024-12-22   0.0        NaN      Southampton
# 2838  2839         Fulham  2024-09-28   0.0          @  Nott'ham Forest
# 2839  2840          Lecce  2024-12-15   0.0        NaN            Monza
# 2840  2841          Lecce  2024-10-29   0.0        NaN    Hellas Verona
# 2841  2842          Lecce  2024-09-15   0.0          @           Torino
#
#                     Comp Result  GF  GA  GD  Poss  G-PK  PK  PKatt  PKm  \
# ...

# %%
dfs= [df_AGK, df_ArW, df_AtD, df_Car, df_CrA, df_Crd, df_GcA, df_GKA, df_Gls, df_Misc, df_OPA, df_Pas, df_PkA, df_PkD, 
      df_PsT, df_Rec, df_ScA, df_ShA, df_Tch, df_Tkl, df_xG, df_xGK]#df_Tkl
common_cols = set(dfs[0].columns)
df_AGK.sort_values(by=["Team", "Opp", "Date"], inplace= True)
df_AGK.reset_index(drop=True, inplace= True) 
for df in dfs[1:]:
    df.sort_values(by=["Team", "Opp", "Date"], inplace=True)
    df.reset_index(drop=True, inplace= True)
    common_cols &= set(df.columns)
common_cols = list(common_cols)  # Convert to list
common_cols
# Out:
# ['Date',
#  'PK',
#  'PKm',
#  'G-PK',
#  'GF',
#  'Poss',
#  'Match Report',
#  'GD',
#  'GA',
#  'Result',
#  'Rk',
#  'Unnamed: 4',
#  'PKatt',
#  'Comp',
#  'Opp',
#  'Team']

# %%
df_cols= df_ArW[common_cols]
for df in dfs:
    df.drop(columns=common_cols, inplace= True)
dfs.append(df_cols)

# %%
df_Teams_Games= pd.concat([df for df in dfs], axis=1)
df_Teams_Games
# Out:
#       Att (GK)  Thr  Pa Launch%  Pa AvgLen  Won  Lost  Won%  Att To  Succ  \
# 0           42    4        52.4       36.8   17    16  51.5      15     6
# 1           32    5        62.5       47.7   17    13  56.7      10     3
# 2           20    4        85.0       54.9   10     7  58.8      15     5
# 3           14    3        57.1       48.2   18    17  51.4       9     3
# 4           18    1        66.7       44.7    9    14  39.1      17     6
# ...        ...  ...         ...        ...  ...   ...   ...     ...   ...
# 2837        21    5        38.1       37.0    5     8  38.5      25    12
# 2838        19    3        63.2       45.5   14    12  53.8      13     4
# 2839        29    2        65.5       43.4    8    14  36.4      16     5
# 2840        34    2        70.6       45.0   24    20  54.5      12     8
# 2841        21    4        52.4       44.3    9    11  45.0      21     8
#
#       Succ%  ...  Match Report  GD  GA  Result    Rk  Unnamed: 4  PKatt  \
# ...

# %%
cols = common_cols + [col for col in df_Teams_Games.columns if col not in common_cols]
df1= df_Teams_Games[cols]
df1
# Out:
#             Date  PK  PKm  G-PK  GF  Poss  Match Report  GD  GA Result  ...  \
# 0     2024-12-15   0    0     1   1    52  Match Report   0   1  D 1-1  ...
# 1     2024-11-23   1    0     0   1    30  Match Report  -1   2  L 1-2  ...
# 2     2024-10-06   0    0     0   0    29  Match Report  -3   3  L 0-3  ...
# 3     2025-02-02   0    0     0   0    31  Match Report  -1   1  L 0-1  ...
# 4     2024-08-25   0    0     0   0    38  Match Report   0   0  D 0-0  ...
# ...          ...  ..  ...   ...  ..   ...           ...  ..  ..    ...  ...
# 2837  2024-11-09   0    0     2   2    29  Match Report   2   0  W 2-0  ...
# 2838  2025-03-15   0    0     2   2    40  Match Report   1   1  W 2-1  ...
# 2839  2024-12-29   0    0     2   2    52  Match Report   0   2  D 2-2  ...
# 2840  2024-12-09   0    0     1   1    46  Match Report  -1   2  L 1-2  ...
# 2841  2025-04-01   0    0     1   1    42  Match Report   1   0  W 1-0  ...
#
# ...

# %%
id= ["Team", "Opp", "Date", "Result", "Unnamed: 4", "GF", "GA", "GD"]
cols2= id+ [col for col in df1.columns if not(col in id)]
df2= df1[cols2].copy()
df2
# Out:
#         Team              Opp        Date Result Unnamed: 4  GF  GA  GD  PK  \
# 0     Alavés    Athletic Club  2024-12-15  D 1-1        NaN   1   1   0   0
# 1     Alavés  Atlético Madrid  2024-11-23  L 1-2          @   1   2  -1   1
# 2     Alavés        Barcelona  2024-10-06  L 0-3        NaN   0   3  -3   0
# 3     Alavés        Barcelona  2025-02-02  L 0-1          @   0   1  -1   0
# 4     Alavés            Betis  2024-08-25  D 0-0        NaN   0   0   0   0
# ...      ...              ...         ...    ...        ...  ..  ..  ..  ..
# 2837  Wolves      Southampton  2024-11-09  W 2-0        NaN   2   0   2   0
# 2838  Wolves      Southampton  2025-03-15  W 2-1          @   2   1   1   0
# 2839  Wolves        Tottenham  2024-12-29  D 2-2          @   2   2   0   0
# 2840  Wolves         West Ham  2024-12-09  L 1-2          @   1   2  -1   0
# 2841  Wolves         West Ham  2025-04-01  W 1-0        NaN   1   0   1   0
#
# ...

# %%
cols_to_delete= ["Match Report", "Rk"]
df2["Date"] = pd.to_datetime(df2["Date"], format="%Y-%m-%d")
df3 = df2.drop(columns= cols_to_delete)
df3
# Out:
#         Team              Opp       Date Result Unnamed: 4  GF  GA  GD  PK  \
# 0     Alavés    Athletic Club 2024-12-15  D 1-1        NaN   1   1   0   0
# 1     Alavés  Atlético Madrid 2024-11-23  L 1-2          @   1   2  -1   1
# 2     Alavés        Barcelona 2024-10-06  L 0-3        NaN   0   3  -3   0
# 3     Alavés        Barcelona 2025-02-02  L 0-1          @   0   1  -1   0
# 4     Alavés            Betis 2024-08-25  D 0-0        NaN   0   0   0   0
# ...      ...              ...        ...    ...        ...  ..  ..  ..  ..
# 2837  Wolves      Southampton 2024-11-09  W 2-0        NaN   2   0   2   0
# 2838  Wolves      Southampton 2025-03-15  W 2-1          @   2   1   1   0
# 2839  Wolves        Tottenham 2024-12-29  D 2-2          @   2   2   0   0
# 2840  Wolves         West Ham 2024-12-09  L 1-2          @   1   2  -1   0
# 2841  Wolves         West Ham 2025-04-01  W 1-0        NaN   1   0   1   0
#
# ...

# %%
df4 = df3.rename(columns={"Unnamed: 4": "H/A"})
df4
# Out:
#         Team              Opp       Date Result  H/A  GF  GA  GD  PK  PKm  \
# 0     Alavés    Athletic Club 2024-12-15  D 1-1  NaN   1   1   0   0    0
# 1     Alavés  Atlético Madrid 2024-11-23  L 1-2    @   1   2  -1   1    0
# 2     Alavés        Barcelona 2024-10-06  L 0-3  NaN   0   3  -3   0    0
# 3     Alavés        Barcelona 2025-02-02  L 0-1    @   0   1  -1   0    0
# 4     Alavés            Betis 2024-08-25  D 0-0  NaN   0   0   0   0    0
# ...      ...              ...        ...    ...  ...  ..  ..  ..  ..  ...
# 2837  Wolves      Southampton 2024-11-09  W 2-0  NaN   2   0   2   0    0
# 2838  Wolves      Southampton 2025-03-15  W 2-1    @   2   1   1   0    0
# 2839  Wolves        Tottenham 2024-12-29  D 2-2    @   2   2   0   0    0
# 2840  Wolves         West Ham 2024-12-09  L 1-2    @   1   2  -1   0    0
# 2841  Wolves         West Ham 2025-04-01  W 1-0  NaN   1   0   1   0    0
#
#       ...  xAG   xA  G-xG np:G-xG  A-xAG  npxG/Sh  FKAtt  PSxG  PSxG/SoT  \
# ...

# %%
df4["H/A"] = df4["H/A"].fillna("H").replace("@", "A")
df4
# Out:
#         Team              Opp       Date Result H/A  GF  GA  GD  PK  PKm  ...  \
# 0     Alavés    Athletic Club 2024-12-15  D 1-1   H   1   1   0   0    0  ...
# 1     Alavés  Atlético Madrid 2024-11-23  L 1-2   A   1   2  -1   1    0  ...
# 2     Alavés        Barcelona 2024-10-06  L 0-3   H   0   3  -3   0    0  ...
# 3     Alavés        Barcelona 2025-02-02  L 0-1   A   0   1  -1   0    0  ...
# 4     Alavés            Betis 2024-08-25  D 0-0   H   0   0   0   0    0  ...
# ...      ...              ...        ...    ...  ..  ..  ..  ..  ..  ...  ...
# 2837  Wolves      Southampton 2024-11-09  W 2-0   H   2   0   2   0    0  ...
# 2838  Wolves      Southampton 2025-03-15  W 2-1   A   2   1   1   0    0  ...
# 2839  Wolves        Tottenham 2024-12-29  D 2-2   A   2   2   0   0    0  ...
# 2840  Wolves         West Ham 2024-12-09  L 1-2   A   1   2  -1   0    0  ...
# 2841  Wolves         West Ham 2025-04-01  W 1-0   H   1   0   1   0    0  ...
#
# ...

# %%
df4["Result"] = df4["Result"].str[0]
df4
# Out:
#         Team              Opp       Date Result H/A  GF  GA  GD  PK  PKm  ...  \
# 0     Alavés    Athletic Club 2024-12-15      D   H   1   1   0   0    0  ...
# 1     Alavés  Atlético Madrid 2024-11-23      L   A   1   2  -1   1    0  ...
# 2     Alavés        Barcelona 2024-10-06      L   H   0   3  -3   0    0  ...
# 3     Alavés        Barcelona 2025-02-02      L   A   0   1  -1   0    0  ...
# 4     Alavés            Betis 2024-08-25      D   H   0   0   0   0    0  ...
# ...      ...              ...        ...    ...  ..  ..  ..  ..  ..  ...  ...
# 2837  Wolves      Southampton 2024-11-09      W   H   2   0   2   0    0  ...
# 2838  Wolves      Southampton 2025-03-15      W   A   2   1   1   0    0  ...
# 2839  Wolves        Tottenham 2024-12-29      D   A   2   2   0   0    0  ...
# 2840  Wolves         West Ham 2024-12-09      L   A   1   2  -1   0    0  ...
# 2841  Wolves         West Ham 2025-04-01      W   H   1   0   1   0    0  ...
#
# ...

# %%
df4.sort_values(by="Date", inplace=True)
df4
# Out:
#                 Team             Opp       Date Result H/A  GF  GA  GD  PK  \
# 993           Girona           Betis 2024-08-15      D   A   1   1   0   0
# 958           Getafe   Athletic Club 2024-08-15      D   A   1   1   0   0
# 337            Betis          Girona 2024-08-15      D   H   1   1   0   0
# 161    Athletic Club          Getafe 2024-08-15      D   H   1   1   0   0
# 2024       Paris S-G        Le Havre 2024-08-16      W   A   4   1   3   1
# ...              ...             ...        ...    ...  ..  ..  ..  ..  ..
# 1425  Leicester City   Newcastle Utd 2025-04-07      L   H   0   3  -3   0
# 404          Bologna          Napoli 2025-04-07      D   H   1   1   0   0
# 1390         Leganés         Osasuna 2025-04-07      D   H   1   1   0   1
# 2005         Osasuna         Leganés 2025-04-07      D   A   1   1   0   0
# 1914   Newcastle Utd  Leicester City 2025-04-07      W   A   3   0   3   0
#
# ...

# %%
df_league = {comp_value: df4[df4["Comp"] == comp_value] for comp_value in df4["Comp"].unique()}

# %%
df_league.keys()
for league in df_league.keys():
    print(str(league)[3:])
# Out:
# La Liga
# Ligue 1
#  Premier League
# Serie A
# Bundesliga

# %%
for league in df_league.keys():
    df_league[league].to_csv(f"../../../{str(league)[3:].strip(' ')}/Teams/Data/Games.csv", index=False)
