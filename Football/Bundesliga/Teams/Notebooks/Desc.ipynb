# %%
import pandas as pd

# %%
df= pd.read_csv("../Data/Games.csv")
df
# Out:
#               Team             Opp        Date Result H/A  GF  GA  GD  PK  \
# 0         Gladbach      Leverkusen  2024-08-23      L   H   2   3  -1   0
# 1       Leverkusen        Gladbach  2024-08-23      W   A   3   2   1   0
# 2         Mainz 05    Union Berlin  2024-08-24      D   H   1   1   0   0
# 3         Freiburg       Stuttgart  2024-08-24      W   H   3   1   2   0
# 4         Augsburg   Werder Bremen  2024-08-24      D   H   2   2   0   0
# ..             ...             ...         ...    ...  ..  ..  ..  ..  ..
# 499  Werder Bremen  Eint Frankfurt  2025-04-05      W   H   2   0   2   0
# 500   Union Berlin       Wolfsburg  2025-04-06      W   H   1   0   1   0
# 501      St. Pauli        Gladbach  2025-04-06      D   H   1   1   0   0
# 502       Gladbach       St. Pauli  2025-04-06      D   A   1   1   0   0
# 503      Wolfsburg    Union Berlin  2025-04-06      L   A   0   1  -1   0
#
#      PKm  ...  xAG   xA  G-xG np:G-xG  A-xAG  npxG/Sh  FKAtt  PSxG  PSxG/SoT  \
# 0      0  ...  0.8  1.1   0.4     0.4   -0.8     0.12      0   2.3      0.14
# 1      1  ...  1.2  1.2   0.3     1.3   -1.2     0.07      1   2.3      0.36
# 2      0  ...  0.7  1.4  -0.2    -0.2   -0.7     0.08      1   0.9      0.19
# 3      0  ...  1.3  1.1   0.9     0.9    0.7     0.17      1   0.9      0.46
# 4      0  ...  0.9  0.9   1.0     1.0    1.1     0.10      0   0.8      0.17
# ..   ...  ...  ...  ...   ...     ...    ...      ...    ...   ...       ...
# 499    0  ...  0.6  0.3   1.0     1.0    1.4     0.09      0   0.0       NaN
# 500    0  ...  0.3  0.7  -0.2    -0.2    0.7     0.09      1   0.3      0.08
# 501    0  ...  1.0  1.0  -0.9    -0.9    0.0     0.07      1   0.9      0.29
# 502    0  ...  0.6  0.4   0.4     0.4    0.4     0.11      0   2.1      0.23
# 503    0  ...  0.5  0.8  -1.9    -1.9   -0.5     0.15      0   0.9      0.29
#
#      PSxG+/-
# 0       -0.7
# 1        0.3
# 2       -0.1
# 3       -0.1
# 4       -1.2
# ..       ...
# 499      0.0
# 500      0.3
# 501     -0.1
# 502      1.1
# 503     -0.1
#
# [504 rows x 157 columns]

# %%
df= df.drop(columns=["Comp"])

# %%
df_teams = {tm: df[df["Team"] == tm] for tm in df["Team"].unique()}

# %%
df_opps= {tm: df[df["Opp"] == tm] for tm in df["Opp"].unique()}

# %%
for team in df_teams.keys():
    df_teams[team].to_csv(f"../Data/{team}.csv", index=False)
    df_opps[team].to_csv(f"../Data/vs {team}.csv", index=False)
