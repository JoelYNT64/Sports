# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_theme(style="darkgrid")

# %%
df= pd.read_csv("../Data/Alavés.csv")
df
# Out:
#       Team              Opp        Date Result H/A  GF  GA  GD  G-PK  PK  ...  \
# 0   Alavés       Celta Vigo  2024-08-16      L   A   1   2  -1     1   0  ...
# 1   Alavés            Betis  2024-08-25      D   H   0   0   0     0   0  ...
# 2   Alavés    Real Sociedad  2024-08-28      W   A   2   1   1     1   1  ...
# 3   Alavés       Las Palmas  2024-09-01      W   H   2   0   2     2   0  ...
# 4   Alavés         Espanyol  2024-09-14      L   A   2   3  -1     2   0  ...
# 5   Alavés          Sevilla  2024-09-20      W   H   2   1   1     2   0  ...
# 6   Alavés      Real Madrid  2024-09-24      L   A   2   3  -1     2   0  ...
# 7   Alavés           Getafe  2024-09-28      L   A   0   2  -2     0   0  ...
# 8   Alavés        Barcelona  2024-10-06      L   H   0   3  -3     0   0  ...
# 9   Alavés       Valladolid  2024-10-18      L   H   2   3  -1     2   0  ...
# 10  Alavés   Rayo Vallecano  2024-10-26      L   A   0   1  -1     0   0  ...
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_goals_scored(team_df, team_name):
    """
    Plots the number of goals scored by a team, distinguishing between home and away games.

    team_df: DataFrame with columns ['Date', 'Goals_Scored', 'Home/Away']
    team_name: Name of the team for the title of the plot
    """
    team_df = team_df.copy()
    
    # Convert Date to datetime
    team_df['Date'] = pd.to_datetime(team_df['Date'])
    
    # Split home and away matches
    home_games = team_df[team_df['H/A'] == 'H']
    away_games = team_df[team_df['H/A'] == 'A']

    # Plot the data
    plt.figure(figsize=(10, 5))
    sns.scatterplot(x= home_games['Date'], y= home_games['GF'], label='Home Goals')
    sns.scatterplot(x= away_games['Date'], y= away_games['GF'], label='Away Goals')

    # Labels and title
    plt.xlabel('Date')
    plt.ylabel('Goals Scored')
    plt.title(f'Goals Scored by {team_name} (Home vs Away)')
    plt.legend()
    plt.xticks(rotation=45)
    plt.grid(True)
    
    # Show the plot
    plt.show()
    
    plt.figure(figsize=(10, 5))
    sns.scatterplot(x= home_games['Date'], y= home_games['GA'], label='Home Goals')
    sns.scatterplot(x= away_games['Date'], y= away_games['GA'], label='Away Goals')

    # Labels and title
    plt.xlabel('Date')
    plt.ylabel('Goals Allowed')
    plt.title(f'Goals Allowed by {team_name} (Home vs Away)')
    plt.legend()
    plt.xticks(rotation=45)
    plt.grid(True)
    
    # Show the plot
    plt.show()

# Example usage
# team_df = pd.read_csv("team_x.csv")  # Load the dataset
# plot_goals_scored(team_df, "Team X")

# %%
plot_goals_scored(df, "Alaves")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="darkgrid")

df= pd.read_csv("../Data/Espanyol.csv")
df

import pandas as pd
import matplotlib.pyplot as plt

def plot_goals_scored(team_df, team_name):
    """
    Plots the number of goals scored by a team, distinguishing between home and away games.

    team_df: DataFrame with columns ['Date', 'Goals_Scored', 'Home/Away']
    team_name: Name of the team for the title of the plot
    """
    team_df = team_df.copy()
    
    # Convert Date to datetime
    team_df['Date'] = pd.to_datetime(team_df['Date'])
    
    # Split home and away matches
    home_games = team_df[team_df['H/A'] == 'H']
    away_games = team_df[team_df['H/A'] == 'A']

    # Plot the data
    plt.figure(figsize=(10, 5))
    sns.scatterplot(x= home_games['Date'], y= home_games['GF'], label='Home Goals')
    sns.scatterplot(x= away_games['Date'], y= away_games['GF'], label='Away Goals')

    # Labels and title
    plt.xlabel('Date')
    plt.ylabel('Goals Scored')
    plt.title(f'Goals Scored by {team_name} (Home vs Away)')
    plt.legend()
    plt.xticks(rotation=45)
    plt.grid(True)
    
    # Show the plot
    plt.show()
    
    plt.figure(figsize=(10, 5))
    sns.scatterplot(x= home_games['Date'], y= home_games['GA'], label='Home Goals')
    sns.scatterplot(x= away_games['Date'], y= away_games['GA'], label='Away Goals')

    # Labels and title
    plt.xlabel('Date')
    plt.ylabel('Goals Allowed')
    plt.title(f'Goals Allowed by {team_name} (Home vs Away)')
    plt.legend()
    plt.xticks(rotation=45)
    plt.grid(True)
    
    # Show the plot
    plt.show()

# Example usage
# team_df = pd.read_csv("team_x.csv")  # Load the dataset
# plot_goals_scored(team_df, "Team X")


plot_goals_scored(df, "Espagnol")import pandas as pd
