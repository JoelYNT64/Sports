# %%
import pandas as pd

# %%
df= pd.read_csv("../Data/Games.csv")
df
# Out:
#               Team            Opp        Date Result H/A  GF  GA  GD  PK  PKm  \
# 0           Girona          Betis  2024-08-15      D   A   1   1   0   0    0
# 1           Getafe  Athletic Club  2024-08-15      D   A   1   1   0   0    0
# 2            Betis         Girona  2024-08-15      D   H   1   1   0   0    0
# 3    Athletic Club         Getafe  2024-08-15      D   H   1   1   0   0    0
# 4          Sevilla     Las Palmas  2024-08-16      D   A   2   2   0   0    0
# ..             ...            ...         ...    ...  ..  ..  ..  ..  ..  ...
# 593     Las Palmas  Real Sociedad  2025-04-06      L   H   1   3  -2   0    0
# 594  Real Sociedad     Las Palmas  2025-04-06      W   A   3   1   2   0    0
# 595  Athletic Club     Villarreal  2025-04-06      D   A   0   0   0   0    0
# 596        Leganés        Osasuna  2025-04-07      D   H   1   1   0   1    0
# 597        Osasuna        Leganés  2025-04-07      D   A   1   1   0   0    0
#
#      ...  xAG   xA  G-xG np:G-xG  A-xAG  npxG/Sh  FKAtt  PSxG  PSxG/SoT  \
# 0    ...  1.6  1.4  -0.6    -0.6   -0.6     0.12      0   1.3      0.34
# 1    ...  0.7  0.3   0.2     0.2    0.3     0.09      0   0.8      0.23
# 2    ...  1.1  0.9  -0.4    -0.4   -0.1     0.07      0   1.0      0.49
# 3    ...  0.3  0.5   0.7     0.7    0.7     0.05      1   1.0      0.49
# 4    ...  1.5  1.5  -0.8    -0.8   -0.5     0.10      0   1.1      0.23
# ..   ...  ...  ...   ...     ...    ...      ...    ...   ...       ...
# 593  ...  1.6  1.7  -1.0    -1.0   -0.6     0.15      0   2.4      0.31
# 594  ...  1.6  1.2   0.6     0.6   -0.6     0.19      0   1.8      0.35
# 595  ...  0.7  0.9  -0.8    -0.8   -0.7     0.08      0   0.4      0.09
# 596  ...  0.5  0.7  -0.7    -1.0   -0.5     0.08      1   2.0      0.33
# 597  ...  1.9  1.9  -1.2    -1.2   -0.9     0.18      0   2.7      0.26
#
#      PSxG+/-
# 0        0.3
# 1       -0.2
# 2        0.0
# 3        0.0
# 4        0.1
# ..       ...
# 593     -0.6
# 594      0.8
# 595      0.4
# 596      1.0
# 597      1.7
#
# [598 rows x 157 columns]

# %%
df= df.drop(columns=["Comp"])

# %%
df_teams = {tm: df[df["Team"] == tm] for tm in df["Team"].unique()}

# %%
df_opps= {tm: df[df["Opp"] == tm] for tm in df["Opp"].unique()}

# %%
for team in df_teams.keys():
    df_teams[team].to_csv(f"../Data/{team}.csv", index=False)
    df_opps[team].to_csv(f"../Data/vs {team}.csv", index=False)
