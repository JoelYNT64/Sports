# %%
import pandas as pd

# %%
df= pd.read_csv("../Data/Games.csv")
df
# Out:
#               Team            Opp        Date Result H/A  GF  GA  GD  Poss  \
# 0    Athletic Club         Getafe  2024-08-15      D   H   1   1   0    68
# 1           Girona          Betis  2024-08-15      D   A   1   1   0    61
# 2            Betis         Girona  2024-08-15      D   H   1   1   0    39
# 3           Getafe  Athletic Club  2024-08-15      D   A   1   1   0    32
# 4          Sevilla     Las Palmas  2024-08-16      D   A   2   2   0    52
# ..             ...            ...         ...    ...  ..  ..  ..  ..   ...
# 497    Real Madrid         Girona  2025-02-23      W   H   2   0   2    63
# 498       Mallorca        Sevilla  2025-02-24      D   A   1   1   0    47
# 499        Sevilla       Mallorca  2025-02-24      D   H   1   1   0    53
# 500     Valladolid     Las Palmas  2025-02-28      D   H   1   1   0    64
# 501     Las Palmas     Valladolid  2025-02-28      D   A   1   1   0    36
#
#            Comp  ...  xAG   xA  G-xG  np:G-xG  A-xAG  npxG/Sh  FKAtt  PSxG  \
# 0    es La Liga  ...  0.3  0.5   0.7      0.7    0.7     0.05      1   1.0
# 1    es La Liga  ...  1.6  1.4  -0.6     -0.6   -0.6     0.12      0   1.3
# 2    es La Liga  ...  1.1  0.9  -0.4     -0.4   -0.1     0.07      0   1.0
# 3    es La Liga  ...  0.7  0.3   0.2      0.2    0.3     0.09      0   0.8
# 4    es La Liga  ...  1.5  1.5  -0.8     -0.8   -0.5     0.10      0   1.1
# ..          ...  ...  ...  ...   ...      ...    ...      ...    ...   ...
# 497  es La Liga  ...  1.9  2.0  -0.2     -0.2   -0.9     0.10      0   0.2
# 498  es La Liga  ...  1.7  2.0  -1.3     -1.3   -1.7     0.18      0   1.0
# 499  es La Liga  ...  0.8  1.8  -0.3     -0.3   -0.8     0.07      0   1.0
# 500  es La Liga  ...  1.6  1.5  -1.0     -1.0   -0.6     0.09      1   0.5
# 501  es La Liga  ...  0.1  0.4   0.8      0.8    0.9     0.04      0   1.6
#
#      PSxG/SoT  PSxG+/-
# 0        0.49      0.0
# 1        0.34      0.3
# 2        0.49      0.0
# 3        0.23     -0.2
# 4        0.23      0.1
# ..        ...      ...
# 497      0.09      0.2
# 498      0.33      0.0
# 499      0.48      0.0
# 500      0.15     -0.5
# 501      0.23      0.6
#
# [502 rows x 157 columns]

# %%
df= df.drop(columns=["Comp"])

# %%
df_teams = {tm: df[df["Team"] == tm] for tm in df["Team"].unique()}

# %%
df_opps= {tm: df[df["Opp"] == tm] for tm in df["Opp"].unique()}

# %%
for team in df_teams.keys():
    df_teams[team].to_csv(f"../Data/{team}.csv", index=False)
    df_opps[team].to_csv(f"../Data/vs {team}.csv", index=False)
