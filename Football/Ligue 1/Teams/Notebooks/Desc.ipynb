# %%
import pandas as pd

# %%
df= pd.read_csv("../Data/Games.csv")
df
# Out:
#               Team        Opp        Date Result H/A  GF  GA  GD  G-PK  PK  \
# 0        Paris S-G   Le Havre  2024-08-16      W   A   4   1   3     3   1
# 1         Le Havre  Paris S-G  2024-08-16      L   H   1   4  -3     1   0
# 2            Brest  Marseille  2024-08-17      L   H   1   5  -4     1   0
# 3            Reims      Lille  2024-08-17      L   H   0   2  -2     0   0
# 4    Saint-Étienne     Monaco  2024-08-17      L   A   0   1  -1     0   0
# ..             ...        ...         ...    ...  ..  ..  ..  ..   ...  ..
# 479         Rennes     Angers  2025-03-30      W   A   3   0   3     3   0
# 480          Brest   Toulouse  2025-03-30      W   A   4   2   2     4   0
# 481       Toulouse      Brest  2025-03-30      L   H   2   4  -2     2   0
# 482           Lens      Lille  2025-03-30      L   A   0   1  -1     0   0
# 483    Montpellier    Auxerre  2025-03-30      L   A   0   1  -1     0   0
#
#      ...  xAG   xA  G-xG  np:G-xG  A-xAG  npxG/Sh  FKAtt  PSxG  PSxG/SoT  \
# 0    ...  2.0  1.1   1.1      0.9    1.0     0.15      0   0.2      0.09
# 1    ...  0.2  0.3   0.8      0.8    0.8     0.04      0   4.5      0.43
# 2    ...  0.3  0.3  -0.3      0.5    0.7     0.06      0   3.0      0.24
# 3    ...  0.1  0.2  -0.1     -0.1   -0.1     0.04      0   2.2      0.37
# 4    ...  0.2  0.2  -0.4     -0.4   -0.2     0.04      0   0.8      0.14
# ..   ...  ...  ...   ...      ...    ...      ...    ...   ...       ...
# 479  ...  1.3  1.3   1.5      1.5    1.7     0.11      0   1.2      0.30
# 480  ...  0.7  0.5   2.7      2.7    1.3     0.14      0   1.3      0.33
# 481  ...  1.2  2.0   0.0      0.0    0.8     0.12      1   2.7      0.58
# 482  ...  0.4  0.7  -0.4     -0.4   -0.4     0.08      1   2.2      0.45
# 483  ...  0.3  0.7  -0.5     -0.5   -0.3     0.04      0   1.4      0.23
#
#      PSxG+/-
# 0       -0.8
# 1        0.5
# 2       -2.0
# 3        0.2
# 4       -0.2
# ..       ...
# 479      1.2
# 480     -0.7
# 481     -1.3
# 482      1.2
# 483      0.4
#
# [484 rows x 157 columns]

# %%
df= df.drop(columns=["Comp"])

# %%
df_teams = {tm: df[df["Team"] == tm] for tm in df["Team"].unique()}

# %%
df_opps= {tm: df[df["Opp"] == tm] for tm in df["Opp"].unique()}

# %%
for team in df_teams.keys():
    df_teams[team].to_csv(f"../Data/{team}.csv", index=False)
    df_opps[team].to_csv(f"../Data/vs {team}.csv", index=False)
