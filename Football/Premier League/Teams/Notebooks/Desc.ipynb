# %%
import pandas as pd

# %%
df= pd.read_csv("../Data/Games.csv")
df
# Out:
#                 Team              Opp        Date Result H/A  GF  GA  GD  \
# 0     Manchester Utd           Fulham  2024-08-16      W   H   1   0   1
# 1             Fulham   Manchester Utd  2024-08-16      L   A   0   1  -1
# 2            Everton         Brighton  2024-08-17      L   H   0   3  -3
# 3    Nott'ham Forest      Bournemouth  2024-08-17      D   H   1   1   0
# 4             Wolves          Arsenal  2024-08-17      L   A   0   2  -2
# ..               ...              ...         ...    ...  ..  ..  ..  ..
# 537          Arsenal  Nott'ham Forest  2025-02-26      D   A   0   0   0
# 538          Everton        Brentford  2025-02-26      D   A   1   1   0
# 539  Manchester City        Tottenham  2025-02-26      W   A   1   0   1
# 540         West Ham   Leicester City  2025-02-27      W   H   2   0   2
# 541   Leicester City         West Ham  2025-02-27      L   A   0   2  -2
#
#      Poss                Comp  ...  xAG   xA  G-xG  np:G-xG  A-xAG  npxG/Sh  \
# 0      55  eng Premier League  ...  2.0  1.0  -1.4     -1.4   -1.0     0.17
# 1      45  eng Premier League  ...  0.4  0.5  -0.4     -0.4   -0.4     0.04
# 2      40  eng Premier League  ...  0.2  0.7  -0.5     -0.5   -0.2     0.05
# 3      53  eng Premier League  ...  0.5  0.8  -0.3     -0.3   -0.5     0.10
# 4      47  eng Premier League  ...  0.2  0.3  -0.5     -0.5   -0.2     0.05
# ..    ...                 ...  ...  ...  ...   ...      ...    ...      ...
# 537    64  eng Premier League  ...  1.0  0.9  -1.0     -1.0   -1.0     0.08
# 538    48  eng Premier League  ...  1.0  0.5  -0.5     -0.5    0.0     0.11
# 539    45  eng Premier League  ...  1.6  0.8  -1.1     -1.1   -1.6     0.18
# 540    58  eng Premier League  ...  1.1  1.0  -0.3     -0.3   -1.1     0.21
# 541    42  eng Premier League  ...  0.2  0.2  -0.4     -0.4   -0.2     0.04
#
#      FKAtt  PSxG  PSxG/SoT  PSxG+/-
# 0        0   0.9      0.46      0.9
# 1        0   2.1      0.41      1.1
# 2        0   2.4      0.47     -0.6
# 3        0   1.2      0.30      0.2
# 4        1   1.7      0.28     -0.3
# ..     ...   ...       ...      ...
# 537      0   0.5      0.23      0.5
# 538      0   0.9      0.30     -0.1
# 539      1   1.6      0.28      1.6
# 540      0   0.2      0.12      0.2
# 541      1   0.7      0.42     -0.3
#
# [542 rows x 157 columns]

# %%
df= df.drop(columns=["Comp"])

# %%
df_teams = {tm: df[df["Team"] == tm] for tm in df["Team"].unique()}

# %%
df_opps= {tm: df[df["Opp"] == tm] for tm in df["Opp"].unique()}

# %%
for team in df_teams.keys():
    df_teams[team].to_csv(f"../Data/{team}.csv", index=False)
    df_opps[team].to_csv(f"../Data/vs {team}.csv", index=False)
