# %%
import pandas as pd

# %%
df= pd.read_csv("../Data/Games.csv")
df
# Out:
#                Team             Opp        Date Result H/A  GF  GA  GD  PK  \
# 0    Manchester Utd          Fulham  2024-08-16      W   H   1   0   1   0
# 1            Fulham  Manchester Utd  2024-08-16      L   A   0   1  -1   0
# 2      Ipswich Town       Liverpool  2024-08-17      L   H   0   2  -2   0
# 3     Newcastle Utd     Southampton  2024-08-17      W   H   1   0   1   0
# 4           Everton        Brighton  2024-08-17      L   H   0   3  -3   0
# ..              ...             ...         ...    ...  ..  ..  ..  ..  ..
# 613     Southampton       Tottenham  2025-04-06      L   A   1   3  -2   0
# 614         Chelsea       Brentford  2025-04-06      D   A   0   0   0   0
# 615       Brentford         Chelsea  2025-04-06      D   H   0   0   0   0
# 616  Leicester City   Newcastle Utd  2025-04-07      L   H   0   3  -3   0
# 617   Newcastle Utd  Leicester City  2025-04-07      W   A   3   0   3   0
#
#      PKm  ...  xAG   xA  G-xG np:G-xG  A-xAG  npxG/Sh  FKAtt  PSxG  PSxG/SoT  \
# 0      0  ...  2.0  1.0  -1.4    -1.4   -1.0     0.17      0   0.9      0.46
# 1      0  ...  0.4  0.5  -0.4    -0.4   -0.4     0.04      0   2.1      0.41
# 2      0  ...  0.3  0.2  -0.5    -0.5   -0.3     0.06      0   2.3      0.47
# 3      0  ...  0.3  0.2   0.7     0.7    0.7     0.08      0   0.4      0.14
# 4      0  ...  0.2  0.7  -0.5    -0.5   -0.2     0.05      0   2.4      0.47
# ..   ...  ...  ...  ...   ...     ...    ...      ...    ...   ...       ...
# 613    0  ...  1.0  0.5   0.0     0.0    0.0     0.09      0   3.5      0.35
# 614    0  ...  1.0  0.7  -1.2    -1.2   -1.0     0.06      0   0.5      0.24
# 615    0  ...  1.0  1.8  -1.1    -1.1   -1.0     0.13      1   1.1      0.22
# 616    0  ...  0.4  0.6  -0.5    -0.5   -0.4     0.06      0   2.9      0.59
# 617    0  ...  1.0  0.8  -0.2    -0.2    0.0     0.21      1   0.4      0.18
#
#      PSxG+/-
# 0        0.9
# 1        1.1
# 2        0.3
# 3        0.4
# 4       -0.6
# ..       ...
# 613      0.5
# 614      0.5
# 615      1.1
# 616     -0.1
# 617      0.4
#
# [618 rows x 157 columns]

# %%
df= df.drop(columns=["Comp"])

# %%
df_teams = {tm: df[df["Team"] == tm] for tm in df["Team"].unique()}

# %%
df_opps= {tm: df[df["Opp"] == tm] for tm in df["Opp"].unique()}

# %%
for team in df_teams.keys():
    df_teams[team].to_csv(f"../Data/{team}.csv", index=False)
    df_opps[team].to_csv(f"../Data/vs {team}.csv", index=False)
