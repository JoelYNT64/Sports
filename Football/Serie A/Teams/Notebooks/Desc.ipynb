# %%
import pandas as pd

# %%
df= pd.read_csv("../Data/Games.csv")
df
# Out:
#               Team            Opp        Date Result H/A  GF  GA  GD  G-PK  \
# 0       Fiorentina          Parma  2024-08-17      D   A   1   1   0     1
# 1            Parma     Fiorentina  2024-08-17      D   H   1   1   0     1
# 2            Monza         Empoli  2024-08-17      D   A   0   0   0     0
# 3            Inter          Genoa  2024-08-17      D   A   2   2   0     2
# 4            Milan         Torino  2024-08-17      D   H   2   2   0     2
# ..             ...            ...         ...    ...  ..  ..  ..  ..   ...
# 595       Atalanta     Fiorentina  2025-03-30      L   A   0   1  -1     0
# 596         Torino          Lazio  2025-03-31      D   A   1   1   0     1
# 597          Parma  Hellas Verona  2025-03-31      D   A   0   0   0     0
# 598  Hellas Verona          Parma  2025-03-31      D   H   0   0   0     0
# 599          Lazio         Torino  2025-03-31      D   H   1   1   0     1
#
#      PK  ...  xAG   xA  G-xG  np:G-xG  A-xAG  npxG/Sh  FKAtt  PSxG  PSxG/SoT  \
# 0     0  ...  0.3  0.3   0.3      0.3   -0.3     0.05      1   1.5      0.26
# 1     0  ...  1.0  0.5  -0.7     -0.7    0.0     0.13      0   1.5      0.21
# 2     0  ...  0.3  0.4  -0.3     -0.3   -0.3     0.06      0   0.2      0.09
# 3     0  ...  1.2  1.6   0.1      0.1    0.8     0.12      1   2.1      0.16
# 4     0  ...  1.3  1.3  -0.1     -0.1   -0.3     0.08      0   1.3      0.44
# ..   ..  ...  ...  ...   ...      ...    ...      ...    ...   ...       ...
# 595   0  ...  1.0  1.8  -1.1     -1.1   -1.0     0.12      0   1.5      0.42
# 596   0  ...  0.3  0.5   0.6      0.6   -0.3     0.06      0   1.8      0.30
# 597   0  ...  0.4  0.9  -0.5     -0.5   -0.4     0.05      1   0.0       NaN
# 598   0  ...  0.2  0.2  -0.4     -0.4   -0.2     0.07      0   0.1      0.07
# 599   0  ...  0.9  1.1  -0.2     -0.2    0.1     0.07      0   0.5      0.23
#
#      PSxG+/-
# 0        0.5
# 1        0.5
# 2        0.2
# 3        0.1
# 4        0.3
# ..       ...
# 595      0.5
# 596      0.8
# 597      0.0
# 598      0.1
# 599     -0.5
#
# [600 rows x 157 columns]

# %%
df= df.drop(columns=["Comp"])

# %%
df_teams = {tm: df[df["Team"] == tm] for tm in df["Team"].unique()}

# %%
df_opps= {tm: df[df["Opp"] == tm] for tm in df["Opp"].unique()}

# %%
for team in df_teams.keys():
    df_teams[team].to_csv(f"../Data/{team}.csv", index=False)
    df_opps[team].to_csv(f"../Data/vs {team}.csv", index=False)
