# %%
import pandas as pd

# %%
df= pd.read_csv("../Data/Games.csv")
df
# Out:
#            Team         Opp        Date Result H/A  GF  GA  GD  Poss  \
# 0        Empoli       Monza  2024-08-17      D   H   0   0   0    39
# 1         Inter       Genoa  2024-08-17      D   A   2   2   0    68
# 2         Genoa       Inter  2024-08-17      D   H   2   2   0    32
# 3         Milan      Torino  2024-08-17      D   H   2   2   0    56
# 4    Fiorentina       Parma  2024-08-17      D   A   1   1   0    61
# ..          ...         ...         ...    ...  ..  ..  ..  ..   ...
# 517        Roma       Monza  2025-02-24      W   H   4   0   4    65
# 518     Bologna       Milan  2025-02-27      W   H   2   1   1    57
# 519       Milan     Bologna  2025-02-27      L   A   1   2  -1    43
# 520       Lecce  Fiorentina  2025-02-28      L   A   0   1  -1    52
# 521  Fiorentina       Lecce  2025-02-28      W   H   1   0   1    48
#
#            Comp  ...  xAG   xA  G-xG  np:G-xG  A-xAG  npxG/Sh  FKAtt  PSxG  \
# 0    it Serie A  ...  0.3  0.3  -0.5     -0.5   -0.3     0.04      1   0.1
# 1    it Serie A  ...  1.2  1.6   0.1      0.1    0.8     0.12      1   2.1
# 2    it Serie A  ...  0.3  0.5  -0.1      0.8   -0.3     0.10      1   2.9
# 3    it Serie A  ...  1.3  1.3  -0.1     -0.1   -0.3     0.08      0   1.3
# 4    it Serie A  ...  0.3  0.3   0.3      0.3   -0.3     0.05      1   1.5
# ..          ...  ...  ...  ...   ...      ...    ...      ...    ...   ...
# 517  it Serie A  ...  1.4  1.0   2.5      2.5    2.6     0.06      0   0.8
# 518  it Serie A  ...  2.1  1.2   0.0      0.0   -0.1     0.15      0   1.2
# 519  it Serie A  ...  0.8  0.3   0.2      0.2    0.2     0.10      0   1.7
# 520  it Serie A  ...  0.6  0.4  -0.8     -0.8   -0.6     0.10      0   0.5
# 521  it Serie A  ...  0.8  0.4  -0.6      0.2    0.2     0.09      0   0.3
#
#      PSxG/SoT  PSxG+/-
# 0        0.14      0.1
# 1        0.16      0.1
# 2        0.41      0.9
# 3        0.44      0.3
# 4        0.26      0.5
# ..        ...      ...
# 517      0.40      0.8
# 518      0.29      0.2
# 519      0.43     -0.3
# 520      0.14     -0.5
# 521      0.11      0.3
#
# [522 rows x 157 columns]

# %%
df= df.drop(columns=["Comp"])

# %%
df_teams = {tm: df[df["Team"] == tm] for tm in df["Team"].unique()}

# %%
df_opps= {tm: df[df["Opp"] == tm] for tm in df["Opp"].unique()}

# %%
for team in df_teams.keys():
    df_teams[team].to_csv(f"../Data/{team}.csv", index=False)
    df_opps[team].to_csv(f"../Data/vs {team}.csv", index=False)
