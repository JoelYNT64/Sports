# %%
import pybaseball as bb
import pandas as pd

# %%
dir(bb)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'all_star_full',
#  'all_star_game_logs',
#  'amateur_draft',
#  'amateur_draft_by_team',
#  'appearances',
#  'awards_managers',
#  'awards_players',
#  'awards_share_managers',
#  'awards_share_players',
#  'batting',
#  'batting_leaders',
#  'batting_post',
#  'batting_stats',
#  'batting_stats_bref',
#  'batting_stats_range',
#  'bwar_bat',
#  'bwar_pitch',
#  'cache',
#  'chadwick_register',
#  'college_playing',
#  'datahelpers',
#  'datasources',
#  'division_series_logs',
#  'download_lahman',
#  'enums',
#  'events',
#  'fangraphs_teams',
#  'fg_batting_data',
#  'fg_pitching_data',
#  'fg_team_batting_data',
#  'fg_team_fielding_data',
#  'fg_team_pitching_data',
#  'fielding',
#  'fielding_leaders',
#  'fielding_of',
#  'fielding_of_split',
#  'fielding_post',
#  'fielding_stats',
#  'get_splits',
# ...

# %%
bb.batting
# Out:
# <function pybaseball.lahman.batting() -> pandas.core.frame.DataFrame>
